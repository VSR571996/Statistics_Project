# %%
#Q.Data Handling:How would you handle missing values in a dataset? Describe at least two methods
#Ans -
#Delete the row and column with missing data
#Imputing missing values with mean/median/mode
#Imputing missing values with mean/median/mode of group
#Imputation method for categorical columns
#Forward Fill and Backward Fill
#Use Interpolation
#There are two types of Statistics
#1.descriptive Statistics
#2.inferential Statistics 
#descriptive Statistics- The Data or Collection Data are described in a summarized way
#inferential Statistics- We make use of it in order to explain the descriptive kind

#Q.Explain why it might be necessary to convert data types before performing and analysis
#Ans
#To ensure compatibility with different systems or software requirements

#Q.Statistical Analysis:
#What is a T-test, and in what scenarios would you use it? Provide an example
#based on sales data
#ans-
#A t test is a statistical test that is used to compare the means of two groups. 
#It is often used in hypothesis testing to determine 
#whether a process or treatment actually has an effect on the 
#population of interest, or whether two groups are different from one another.

#Q.What is univariate analysis, and what are its key purposes?
#Ans -
#Univariate analysis is the simplest form of analyzing data. 
#Uni means "one", so the data has only one variable (univariate). 
#Univariate data requires to analyze each variable separately. 

#Q.Explain the difference between univariate and bivariate analysis. Provide anexample of each.
#Univariate analysis focuses on understanding individual variables
#example - Quantity ordered new is univariate

#Bivariate analysis examines relationships between two variables
#example - Sales and count depending on each other so its bivariate

#Q.Data Visualization:
#What are the benefits of using a correlation matrix in data analysis? How would you interpret the results?
#Ans -
#We can use a correlation matrix to summarize a large data set and to identify patterns 
#and make a decision according to it. We can also see which variable is 
#more correlated to which variable, and we can visualize our results. 
#A correlation matrix involves a rows and columns table that shows the variables.

#Q.Why is it important to calculate grouped statistics for key variables? Provide an example using regional sales data
#Ans -
#It helps to focus on important subpopulations and ignores irrelevant ones. 
#Grouping of data improves the accuracy/efficiency of estimation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
# Load the dataset
df=pd.read_excel("sample-superstore-subset-excel.xlsx")

# Display the first few rows and summary statistics
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df.shape
# Out:
# (9426, 24)

# %%
# Handle missing values

# Convert data types if necessary
df.dtypes
# Create any new columns needed for analysis
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
# Univariate analysis
plt.scatter(df.index,df['Quantity ordered new'])
plt.show()

# Bivariate analysis
plt.figure(figsize =(10,8))
sns.histplot(x="Sales",data=df,
alpha=0.8)
plt.xlabel("Sales")             
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Summary statistics for key variables

# Grouped statistics
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %% [markdown]
# ### Conclusion
#
# - Summary of key findings.
# - Insights based on the analysis.

# %% [markdown]
# ## Additional Statistical Analysis

# %%
from scipy.stats import ttest_ind, chi2_contingency

# Example: T-test for sales in different regions

a = "sales same in different region"
b = "sales not same in different region"

c =np.array(df[df.Sales == 'yes'].Region)
d =np.array(df[df.Sales == 'no'].Region)
t, p_value = stats.ttest_ind(c,d, axis = 0)
if p_value < 0.05 :
    print(f'{b} as the p_value ({p_value}>0.05')
else :
    print(f'{a} as the p_value ({p_value}<0.05')



# Example: Chi-square test for independence between Ship Mode and Customer Segment
# Out:
# sales same in different region as the p_value (nan<0.05

# %%
o= "Ship mode not independent to Customer Segment"
p= "Ship mode is independent to Customer Segment"

crosstab= pd.crosstab(df['Ship Mode'], df['Customer Segment'])
chi, p_value, dof, expected= stats.chi2_contingency(crosstab)
if p_value<0.5:
    print(f'{o} as the p_value ({p_value.round(3)})<0.5')
else:
    print(f'{p} as the p_value ({p_value.round(3)})>0.5')
# Out:
# Ship mode is independent to Customer Segment as the p_value (0.949)>0.5

# %%
# Selecting only numeric columns for correlation matrix
plt.figure(figsize= (10,6))
output_corr=df.corr(numeric_only= True)
sns.heatmap(output_corr, annot= True, cmap= "coolwarm")
plt.title("correlation matrix")
plt.show()

# %%
import statsmodels.api as sm

# Example: Linear regression analysis for Sales prediction
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     917.2
# Date:                Fri, 02 Aug 2024   Prob (F-statistic):               0.00
# Time:                        07:32:29   Log-Likelihood:                -85605.
# No. Observations:                9354   AIC:                         1.712e+05
# Df Residuals:                    9350   BIC:                         1.712e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 -463.2564     52.188     -8.877      0.000    -565.557    -360.956
# ...

# %%
# Plotting sales trends over time
plt.figure(figsize=(10, 6))
plt.plot(df["Ship Date"], df["Sales"],marker='p')
plt.title('sales trends over time')
plt.ylabel('Sales')
plt.xlabel('Time')
plt.show()


# Resample sales data by month

# %%
# Plotting profit trends over time
plt.figure(figsize=(10, 6))
plt.plot(df["Ship Date"], df["Profit"],marker='p')
plt.title('profit trends over time')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.show()

# %%
# Identifying top-performing product categories based on total sales and profit




# Plotting total sales by product category







# Plotting total profit by product category
# Out:
# <ipython-input-10-8965ac4d3c76>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_performance.index, y=category_performance['Sales'], palette='viridis')
# <ipython-input-10-8965ac4d3c76>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_performance.index, y=category_performance['Profit'], palette='viridis')
#                        Sales         Profit
# Product Category
# Technology        3514982.03  683097.884748
# Furniture         3038510.90  140343.135390
# Office Supplies   2236064.41  457049.823912

# %%
# Generating summary statistics for each region
df.describe()


# Display summary statistics
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
# Visualizing the correlation between sales and profit
plt.scatter(df.index,df['Sales'])
plt.xlabel("Sales")             
plt.ylabel('Profit')
plt.show





# Displaying the correlation coefficient
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Analyzing seasonal sales trends




# Grouping sales data by month and year
df.describe()
plt.scatter(df.index,df['Month'])
plt.xlabel("Month")             
plt.ylabel('Year')


# Plotting seasonal sales trends
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 8
#       1 # Analyzing seasonal sales trends
#       2
#       3
#       4
#       5
# ...

# %%
# Comparing sales across different ship modes




sales_by_ship_mode
# Out:
# <ipython-input-14-586251ecf454>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_ship_mode.index, y=sales_by_ship_mode.values, palette='magma')
# Ship Mode
# Regular Air       4464427.51
# Delivery Truck    3650525.84
# Express Air        674603.99
# Name: Sales, dtype: float64

# %%
# Ensure column names are clean


# Print column names to verify


# Ensure 'Ship Date' column is datetime type


# Dropping rows where 'Ship Date' couldn't be converted


# Resample sales data by month
# Out:
# Column Names: Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Ship Date', 'Profit', 'Quantity ordered new',
#        'Sales', 'Order ID', 'Order Month', 'Order Year'],
#       dtype='object')
